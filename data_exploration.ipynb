# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
# data = np.zeros(8)
l = []
with open("C:\\Users\\sofie\\OneDrive - Danmarks Tekniske Universitet\\Dokumenter\\DTU\\8. semester\\Biomechanics\\Excel_EMG\\participant7.csv", "r") as f:
    r = csv.reader(f)
    for row in r:
        # np_data = np.array(list(map(int, row)))
        # data = np.vstack((data, np_data))
        l.append(int(row[3]))

# %%
data = np.array(l)
Samp_rate = 25

Jump_T1=Samp_rate*2784
Jump_T2=Samp_rate*2877
plt.plot(data[Jump_T1:Jump_T2])

# %%
data = np.array(l)
Samp_rate = 25

Jump_T1=Samp_rate*(2784)
Jump_T2= Jump_T1+75
plt.plot(data[Jump_T1:Jump_T2])

# %%
m = []
with open("C:\\Users\\sofie\\OneDrive - Danmarks Tekniske Universitet\\Dokumenter\\DTU\\8. semester\\Biomechanics\\Participant21\\participant20.csv", "r") as f:
    r = csv.reader(f)
    for row in r:
        # np_data = np.array(list(map(int, row)))
        # data = np.vstack((data, np_data))
        m.append(int(row[3]))

# %%
data = np.array(m)
Samp_rate = 25


Jump_T1=Samp_rate*6700
Jump_T2=Samp_rate*6756


plt.plot(data[Jump_T1:Jump_T2])

# %%
data = np.array(m)
Samp_rate = 25


Jump_T1=Samp_rate*(6700+60)
Jump_T2=Jump_T1 + 75


plt.plot(data[Jump_T1:Jump_T2])

# %%
plt.vline

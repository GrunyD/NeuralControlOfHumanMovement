# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# %%
# data = np.zeros(8)
l = []
with open("/Users/arnheidur/Desktop/Mastersnám/Vorönn2024/Biomechanics & Neural Control of Human Movement/NeuralControlOfHumanMovement/Bukseprojekt/participant17/participant17.csv", "r") as f:
    r = csv.reader(f)
    for row in r:
        # np_data = np.array(list(map(int, row)))
        # data = np.vstack((data, np_data))
        l.append(int(row[3]))

# %%
# Jumping (the whole signal)

data = np.array(l)
Samp_rate = 25

Activity_T1=Samp_rate*5567
Activity_T2=Samp_rate*5638
plt.plot(data[Activity_T1:Activity_T2])

# %%
# Activity with correct timestamps

data = np.array(l)
Samp_rate = 25

Activity_T1=Samp_rate*(5567)
Activity_T2= Activity_T1+(3*Samp_rate)  # to have 3 seconds for the jump
plt.figure(1)
plt.plot(data[Activity_T1:Activity_T2])
